# %% [markdown]
# # AI Chatbot Using NLP

# %%
import json, re, ast, operator as op, random
import numpy as np
from tqdm import tqdm
import pandas as pd

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tkinter as tk
from tkinter import scrolledtext
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\abuza\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
with open(r"intents.json", "r") as f:
    intents = json.load(f)
print("Number of intents:", len(intents["intents"]))
print("First intent example:", intents["intents"][0].keys())
# Out:
# Number of intents: 23
# First intent example: dict_keys(['intent', 'text', 'responses', 'extension', 'context', 'entityType', 'entities'])

# %%
texts = []
for it in intents["intents"]:
    texts.extend([t.lower() for t in it["text"]])

from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(texts)

# %% [markdown]
# # DO NOT RUN THIS CELL
#
# **Glove.6B.50d.txt** was >100MB therefore this cell was written to achieve the size limit of below 100 MB for each Project.

# %%
""" glove_full = "embeddings/glove.6B.50d.txt"
glove_trim = "embeddings/glove_70mb_50d.txt"

dataset_vocab = set(tokenizer.word_index.keys())
target_words = 150000   # ~60–70 MB

kept = 0
with open(glove_full, "r", encoding="utf-8") as fin, \
     open(glove_trim, "w", encoding="utf-8") as fout:
    for i, line in enumerate(fin):
        word = line.split(" ", 1)[0]
        if i < target_words or word in dataset_vocab:
            fout.write(line)
            kept += 1

print(f"Trimmed GloVe saved: {glove_trim}, words kept = {kept}")
 """
# Out:
# ' glove_full = "embeddings/glove.6B.50d.txt"\nglove_trim = "embeddings/glove_70mb_50d.txt"\n\ndataset_vocab = set(tokenizer.word_index.keys())\ntarget_words = 150000   # ~60–70 MB\n\nkept = 0\nwith open(glove_full, "r", encoding="utf-8") as fin,      open(glove_trim, "w", encoding="utf-8") as fout:\n    for i, line in enumerate(fin):\n        word = line.split(" ", 1)[0]\n        if i < target_words or word in dataset_vocab:\n            fout.write(line)\n            kept += 1\n\nprint(f"Trimmed GloVe saved: {glove_trim}, words kept = {kept}")\n '

# %%
MAX_LEN = 20

texts, labels = [], []
tag_index, tags = {}, []

for it in intents["intents"]:
    tag = it["intent"]  # use your field name
    if tag not in tag_index:
        tag_index[tag] = len(tag_index)
        tags.append(tag)
    for pat in it["text"]:   # your field for training phrases
        texts.append(pat.lower())
        labels.append(tag_index[tag])

tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)
X = pad_sequences(sequences, maxlen=MAX_LEN, padding="post")
y = to_categorical(labels, num_classes=len(tag_index))

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (151, 20)
# Shape of y: (151, 23)

# %%
EMBED_DIM = 50
embeddings_index = {}

with open(r"embeddings\glove_70mb_50d.txt", "r", encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype="float32")
        embeddings_index[word] = coefs

print("Loaded word vectors:", len(embeddings_index))

num_words = len(tokenizer.word_index) + 1
embedding_matrix = np.zeros((num_words, EMBED_DIM))
for word, i in tokenizer.word_index.items():
    vec = embeddings_index.get(word)
    if vec is not None:
        embedding_matrix[i] = vec
# Out:
# Loaded word vectors: 150002

# %%
model = Sequential()
model.add(Embedding(input_dim=num_words,
                    output_dim=EMBED_DIM,
                    weights=[embedding_matrix],
                    input_length=MAX_LEN,
                    trainable=True))
model.add(GlobalAveragePooling1D())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(64, activation="relu"))
model.add(Dense(len(tags), activation="softmax"))

model.compile(optimizer=Adam(1e-3),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

history = model.fit(X, y, epochs=500, batch_size=32,
                    validation_split=0.1, verbose=1)
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.0519 - loss: 3.1304 - val_accuracy: 0.0000e+00 - val_loss: 3.2764
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0444 - loss: 3.1053 - val_accuracy: 0.0000e+00 - val_loss: 3.3081
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0889 - loss: 3.0913 - val_accuracy: 0.0000e+00 - val_loss: 3.3546
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1407 - loss: 3.0718 - val_accuracy: 0.0000e+00 - val_loss: 3.4086
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1037 - loss: 3.0492 - val_accuracy: 0.0000e+00 - val_loss: 3.4776
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1111 - loss: 3.0273 - val_accuracy: 0.0000e+00 - val_loss: 3.5564
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1481 - loss: 3.0112 - val_accuracy: 0.0000e+00 - val_loss: 3.6390
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1778 - loss: 2.9857 - val_accuracy: 0.0000e+00 - val_loss: 3.7393
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1481 - loss: 2.9657 - val_accuracy: 0.0000e+00 - val_loss: 3.8401
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2000 - loss: 2.9326 - val_accuracy: 0.0000e+00 - val_loss: 3.9630
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2148 - loss: 2.8952 - val_accuracy: 0.0000e+00 - val_loss: 4.1102
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2074 - loss: 2.8562 - val_accuracy: 0.0000e+00 - val_loss: 4.2632
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2148 - loss: 2.8173 - val_accuracy: 0.0000e+00 - val_loss: 4.4172
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2963 - loss: 2.7620 - val_accuracy: 0.0000e+00 - val_loss: 4.6167
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2667 - loss: 2.7227 - val_accuracy: 0.0000e+00 - val_loss: 4.8085
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2815 - loss: 2.6792 - val_accuracy: 0.0000e+00 - val_loss: 5.0194
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2519 - loss: 2.6239 - val_accuracy: 0.0000e+00 - val_loss: 5.3015
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3333 - loss: 2.5607 - val_accuracy: 0.0000e+00 - val_loss: 5.5613
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3037 - loss: 2.5227 - val_accuracy: 0.0000e+00 - val_loss: 5.7321
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3333 - loss: 2.4393 - val_accuracy: 0.0000e+00 - val_loss: 5.9397
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3556 - loss: 2.4058 - val_accuracy: 0.0000e+00 - val_loss: 6.1427
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3407 - loss: 2.3654 - val_accuracy: 0.0000e+00 - val_loss: 6.3510
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3556 - loss: 2.2980 - val_accuracy: 0.0000e+00 - val_loss: 6.6252
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3556 - loss: 2.2568 - val_accuracy: 0.0000e+00 - val_loss: 6.8231
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3704 - loss: 2.2010 - val_accuracy: 0.0000e+00 - val_loss: 7.0556
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3778 - loss: 2.1418 - val_accuracy: 0.0000e+00 - val_loss: 7.2424
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4074 - loss: 2.0749 - val_accuracy: 0.0000e+00 - val_loss: 7.5014
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4667 - loss: 2.0682 - val_accuracy: 0.0000e+00 - val_loss: 7.7139
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0654 - val_accuracy: 0.0000e+00 - val_loss: 20.7076
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9852 - loss: 0.0712 - val_accuracy: 0.0000e+00 - val_loss: 20.7948
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0720 - val_accuracy: 0.0000e+00 - val_loss: 20.4881
# Epoch 202/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9926 - loss: 0.0524 - val_accuracy: 0.0000e+00 - val_loss: 20.2471
# Epoch 203/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9852 - loss: 0.0767 - val_accuracy: 0.0000e+00 - val_loss: 20.4370
# Epoch 204/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0675 - val_accuracy: 0.0000e+00 - val_loss: 21.0821
# Epoch 205/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9778 - loss: 0.0910 - val_accuracy: 0.0000e+00 - val_loss: 20.7159
# Epoch 206/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0807 - val_accuracy: 0.0000e+00 - val_loss: 20.4113
# Epoch 207/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9926 - loss: 0.0852 - val_accuracy: 0.0000e+00 - val_loss: 20.2442
# Epoch 208/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0547 - val_accuracy: 0.0000e+00 - val_loss: 20.1993
# Epoch 209/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9926 - loss: 0.0625 - val_accuracy: 0.0000e+00 - val_loss: 20.2762
# Epoch 210/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0698 - val_accuracy: 0.0000e+00 - val_loss: 20.2427
# Epoch 211/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0438 - val_accuracy: 0.0000e+00 - val_loss: 20.3035
# Epoch 212/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0526 - val_accuracy: 0.0000e+00 - val_loss: 20.5318
# Epoch 213/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0528 - val_accuracy: 0.0000e+00 - val_loss: 20.7385
# Epoch 214/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0424 - val_accuracy: 0.0000e+00 - val_loss: 20.7082
# Epoch 215/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0467 - val_accuracy: 0.0000e+00 - val_loss: 20.6876
# Epoch 216/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9926 - loss: 0.0687 - val_accuracy: 0.0000e+00 - val_loss: 20.6904
# Epoch 217/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0480 - val_accuracy: 0.0000e+00 - val_loss: 20.6186
# Epoch 218/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9852 - loss: 0.0692 - val_accuracy: 0.0000e+00 - val_loss: 20.7891
# Epoch 219/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0426 - val_accuracy: 0.0000e+00 - val_loss: 20.7948
# Epoch 220/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0631 - val_accuracy: 0.0000e+00 - val_loss: 20.6763
# Epoch 221/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9926 - loss: 0.0632 - val_accuracy: 0.0000e+00 - val_loss: 20.6595
# Epoch 222/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0371 - val_accuracy: 0.0000e+00 - val_loss: 20.7893
# Epoch 223/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0428 - val_accuracy: 0.0000e+00 - val_loss: 20.9711
# Epoch 224/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0516 - val_accuracy: 0.0000e+00 - val_loss: 21.1667
# Epoch 225/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0472 - val_accuracy: 0.0000e+00 - val_loss: 21.1143
# Epoch 226/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9926 - loss: 0.0542 - val_accuracy: 0.0000e+00 - val_loss: 21.0154
# Epoch 227/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0475 - val_accuracy: 0.0000e+00 - val_loss: 20.9361
# Epoch 228/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0323 - val_accuracy: 0.0000e+00 - val_loss: 20.9527
# Epoch 229/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0370 - val_accuracy: 0.0000e+00 - val_loss: 21.0491
# Epoch 230/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0514 - val_accuracy: 0.0000e+00 - val_loss: 21.2926
# Epoch 231/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0326 - val_accuracy: 0.0000e+00 - val_loss: 21.4542
# Epoch 232/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9926 - loss: 0.0420 - val_accuracy: 0.0000e+00 - val_loss: 21.3759
# Epoch 233/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0508 - val_accuracy: 0.0000e+00 - val_loss: 21.2378
# Epoch 234/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0392 - val_accuracy: 0.0000e+00 - val_loss: 21.1299
# Epoch 235/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.0000e+00 - val_loss: 24.0347
# Epoch 360/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.0000e+00 - val_loss: 23.8184
# Epoch 361/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.0000e+00 - val_loss: 23.8098
# Epoch 362/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.0000e+00 - val_loss: 23.7366
# Epoch 363/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.0000e+00 - val_loss: 23.5434
# Epoch 364/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.0000e+00 - val_loss: 23.4893
# Epoch 365/500
# ...
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.0000e+00 - val_loss: 23.5757
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.0000e+00 - val_loss: 23.8391
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.0000e+00 - val_loss: 23.8368
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.0000e+00 - val_loss: 23.7865
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.0000e+00 - val_loss: 23.9963
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.0000e+00 - val_loss: 24.4928
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.0000e+00 - val_loss: 24.6663
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.0000e+00 - val_loss: 24.5337
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.0000e+00 - val_loss: 24.2467
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.0000e+00 - val_loss: 23.8847
# Epoch 390/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.0000e+00 - val_loss: 23.4546
# Epoch 391/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.0000e+00 - val_loss: 23.3896
# Epoch 392/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.0000e+00 - val_loss: 23.5871
# Epoch 393/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9926 - loss: 0.0332 - val_accuracy: 0.0000e+00 - val_loss: 24.2163
# Epoch 394/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.0000e+00 - val_loss: 24.8308
# Epoch 395/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 0.0000e+00 - val_loss: 24.5124
# Epoch 396/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.0000e+00 - val_loss: 23.9587
# Epoch 397/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.0625 - val_loss: 23.7629
# Epoch 398/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.0000e+00 - val_loss: 23.8457
# Epoch 399/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0193 - val_accuracy: 0.0000e+00 - val_loss: 24.2625
# Epoch 400/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.0000e+00 - val_loss: 24.1203
# Epoch 401/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.0000e+00 - val_loss: 23.9248
# Epoch 402/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.0000e+00 - val_loss: 23.8598
# Epoch 403/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.0000e+00 - val_loss: 23.9021
# Epoch 404/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.0000e+00 - val_loss: 24.0300
# Epoch 405/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.0000e+00 - val_loss: 24.0628
# Epoch 406/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.0000e+00 - val_loss: 24.0182
# Epoch 407/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.0000e+00 - val_loss: 24.1697
# Epoch 408/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.0000e+00 - val_loss: 24.2200
# Epoch 409/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.0000e+00 - val_loss: 24.1264
# Epoch 410/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.0000e+00 - val_loss: 24.0701
# Epoch 411/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9926 - loss: 0.0127 - val_accuracy: 0.0000e+00 - val_loss: 24.1027
# Epoch 412/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.0000e+00 - val_loss: 24.2208
# Epoch 413/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.0000e+00 - val_loss: 24.2580
# Epoch 414/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.0000e+00 - val_loss: 24.1535
# Epoch 415/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.0000e+00 - val_loss: 24.0856
# Epoch 416/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.0000e+00 - val_loss: 24.0625
# Epoch 417/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.0000e+00 - val_loss: 24.0403
# Epoch 418/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.0000e+00 - val_loss: 23.9730
# Epoch 419/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.0000e+00 - val_loss: 23.9584
# Epoch 420/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.0000e+00 - val_loss: 24.1151
# Epoch 421/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.0000e+00 - val_loss: 24.2423
# Epoch 422/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.0000e+00 - val_loss: 24.3348
# Epoch 423/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.0000e+00 - val_loss: 24.4569
# Epoch 424/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.0000e+00 - val_loss: 24.5302
# Epoch 425/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.0000e+00 - val_loss: 24.5557
# Epoch 426/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.0000e+00 - val_loss: 24.5263
# Epoch 427/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.0000e+00 - val_loss: 24.3425
# Epoch 428/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.0000e+00 - val_loss: 24.2143
# Epoch 429/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.0000e+00 - val_loss: 24.2013
# Epoch 430/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.0000e+00 - val_loss: 24.3207
# Epoch 431/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.0000e+00 - val_loss: 24.7780
# Epoch 432/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.0000e+00 - val_loss: 24.8609
# Epoch 433/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.0000e+00 - val_loss: 24.7215
# Epoch 434/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.0000e+00 - val_loss: 24.5955
# Epoch 435/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.0625 - val_loss: 24.5349
# Epoch 436/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.0625 - val_loss: 24.5920
# Epoch 437/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.0000e+00 - val_loss: 24.7502
# Epoch 438/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.0000e+00 - val_loss: 24.8698
# Epoch 439/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.0000e+00 - val_loss: 24.8400
# Epoch 440/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.0625 - val_loss: 24.9051
# Epoch 441/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.0625 - val_loss: 25.0013
# Epoch 442/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.0000e+00 - val_loss: 25.0433
# Epoch 443/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.0000e+00 - val_loss: 24.9822
# Epoch 444/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.0000e+00 - val_loss: 24.9380
# Epoch 445/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.0000e+00 - val_loss: 24.8527
# Epoch 446/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9926 - loss: 0.0128 - val_accuracy: 0.0625 - val_loss: 24.6582
# Epoch 447/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.0625 - val_loss: 24.5897
# Epoch 448/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.0000e+00 - val_loss: 24.7859
# Epoch 449/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.0000e+00 - val_loss: 24.9925
# Epoch 450/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.0000e+00 - val_loss: 25.1859
# Epoch 451/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.0000e+00 - val_loss: 25.2545
# Epoch 452/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.0000e+00 - val_loss: 25.0889
# Epoch 453/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.0000e+00 - val_loss: 24.9985
# Epoch 454/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.0000e+00 - val_loss: 25.0468
# Epoch 455/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.0000e+00 - val_loss: 25.1513
# Epoch 456/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.0000e+00 - val_loss: 25.2531
# Epoch 457/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.0625 - val_loss: 25.2747
# Epoch 458/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.0625 - val_loss: 25.2107
# Epoch 459/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.0625 - val_loss: 25.1956
# Epoch 460/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.0000e+00 - val_loss: 25.1259
# Epoch 461/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.0000e+00 - val_loss: 25.2104
# Epoch 462/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.0000e+00 - val_loss: 25.6353
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.0000e+00 - val_loss: 25.7622
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.0000e+00 - val_loss: 25.6627
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.0000e+00 - val_loss: 25.5976
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.0000e+00 - val_loss: 25.6645
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.0000e+00 - val_loss: 25.6097
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.0000e+00 - val_loss: 25.4816
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.0000e+00 - val_loss: 25.3546
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.0000e+00 - val_loss: 25.2292
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.0000e+00 - val_loss: 25.0957
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.0000e+00 - val_loss: 25.0882
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.0000e+00 - val_loss: 25.2131
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.0000e+00 - val_loss: 25.3383
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.0625 - val_loss: 25.3901
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.0000e+00 - val_loss: 25.3941
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.0000e+00 - val_loss: 25.1822
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.0000e+00 - val_loss: 25.0349
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.0625 - val_loss: 24.9376
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.0625 - val_loss: 24.9279
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.0625 - val_loss: 24.9739
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.0625 - val_loss: 25.0008
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.0000e+00 - val_loss: 24.9213
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.0000e+00 - val_loss: 25.0347
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9852 - loss: 0.0260 - val_accuracy: 0.0000e+00 - val_loss: 25.4542
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.0000e+00 - val_loss: 25.3542
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0185 - val_accuracy: 0.0625 - val_loss: 24.8250
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.0000e+00 - val_loss: 24.5214
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.0000e+00 - val_loss: 24.5435
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.0000e+00 - val_loss: 24.8334
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.0000e+00 - val_loss: 25.0821
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.0000e+00 - val_loss: 25.1471
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.0000e+00 - val_loss: 25.0773
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.0000e+00 - val_loss: 24.9562
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.0000e+00 - val_loss: 24.8657
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.0000e+00 - val_loss: 24.9808
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.0000e+00 - val_loss: 25.0673
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.0000e+00 - val_loss: 25.1223
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.0000e+00 - val_loss: 25.3275
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.0000e+00 - val_loss: 25.5237

# %%
SAFE_OPS = {
    ast.Add: op.add, ast.Sub: op.sub, ast.Mult: op.mul,
    ast.Div: op.truediv, ast.Pow: op.pow, ast.USub: op.neg,
    ast.Mod: op.mod, ast.FloorDiv: op.floordiv
}

def safe_eval(expr):
    def _eval(node):
        if isinstance(node, ast.Num): return node.n
        if isinstance(node, ast.BinOp): return SAFE_OPS[type(node.op)](_eval(node.left), _eval(node.right))
        if isinstance(node, ast.UnaryOp): return SAFE_OPS[type(node.op)](_eval(node.operand))
        raise ValueError("Unsupported")
    return _eval(ast.parse(expr, mode="eval").body)


MATH_WORDS = {
    "plus": "+",
    "minus": "-",
    "times": "*",
    "multiplied by": "*",
    "multiply": "*",
    "x": "*",
    "divide": "/",
    "divided by": "/",
    "over": "/",
    "mod": "%",
    "modulus": "%",
    "remainder": "%",
    "power": "**",
    "to the power of": "**"
}

def normalize_math(text):
    text = text.lower()
    # replace word-based math operators
    for word, sym in MATH_WORDS.items():
        text = text.replace(word, f" {sym} ")
    return text

def is_math_query(text):
    text = normalize_math(text)
    return bool(re.search(r'\d', text) and re.search(r'[\+\-\*\/\%\^]', text))

def parse_math(text):
    text = normalize_math(text)
    # keep only valid characters
    expr = re.sub(r"[^\d\.\+\-\*\/\^\%\(\)]", " ", text)
    expr = expr.replace("^", "**")
    return expr.strip()

# %%
CONF_THRESHOLD = 0.1

def predict_intent(text):
    seq = tokenizer.texts_to_sequences([text.lower()])
    X_inp = pad_sequences(seq, maxlen=MAX_LEN, padding="post")
    preds = model.predict(X_inp, verbose=0)[0]
    idx = int(np.argmax(preds))
    return tags[idx], float(preds[idx])

def get_response(text):
    if is_math_query(text):
        try:
            expr = parse_math(text)
            val = safe_eval(expr)
            return f"{expr} = {val}"
        except:
            return "Sorry, I couldn’t solve that."

    tag, conf = predict_intent(text)
    if conf < CONF_THRESHOLD:
        return "Sorry, I didn't understand. Can you rephrase?"

    for it in intents["intents"]:
        if it["intent"] == tag:   # match with your key
            return random.choice(it["responses"])
    return "Hmm."

# %%
covered = 0
for word in tokenizer.word_index.keys():
    if word in embeddings_index:
        covered += 1
print("Words in tokenizer:", len(tokenizer.word_index))
print("Covered by GloVe:", covered)
# Out:
# Words in tokenizer: 139
# Covered by GloVe: 133

# %%
for it in intents["intents"]:
    print(it["intent"], ":", len(it["text"]))
# Out:
# Greeting : 7
# GreetingResponse : 8
# CourtesyGreeting : 7
# CourtesyGreetingResponse : 8
# CurrentHumanQuery : 7
# NameQuery : 6
# RealNameQuery : 7
# TimeQuery : 7
# Thanks : 6
# NotTalking2U : 7
# UnderstandQuery : 6
# Shutup : 7
# Swearing : 5
# GoodBye : 4
# CourtesyGoodBye : 6
# WhoAmI : 6
# Clever : 7
# Gossip : 6
# Jokes : 6
# PodBayDoor : 7
# PodBayDoorResponse : 7
# SelfAware : 7
# Math : 7

# %%
def debug_intent(text):
    seq = tokenizer.texts_to_sequences([text.lower()])
    X_inp = pad_sequences(seq, maxlen=MAX_LEN, padding="post")
    preds = model.predict(X_inp, verbose=0)[0]
    for i, tag in enumerate(tags):
        print(f"{tag}: {preds[i]:.3f}")
    idx = np.argmax(preds)
    print("→ Predicted:", tags[idx], "Confidence:", preds[idx])

# %%
#debug_intent("hi")
#debug_intent("bye")
#debug_intent("hello there")
debug_intent("thank you")
# Out:
# Greeting: 0.000
# GreetingResponse: 0.000
# CourtesyGreeting: 0.000
# CourtesyGreetingResponse: 0.000
# CurrentHumanQuery: 0.000
# NameQuery: 0.000
# RealNameQuery: 0.000
# TimeQuery: 0.000
# Thanks: 0.999
# NotTalking2U: 0.000
# UnderstandQuery: 0.000
# Shutup: 0.000
# Swearing: 0.000
# GoodBye: 0.000
# CourtesyGoodBye: 0.001
# WhoAmI: 0.000
# Clever: 0.000
# Gossip: 0.000
# Jokes: 0.000
# PodBayDoor: 0.000
# PodBayDoorResponse: 0.000
# SelfAware: 0.000
# Math: 0.000
# → Predicted: Thanks Confidence: 0.99903786

# %%
""" while True:
    user = input("You: ")
    if user.lower() in ["quit","exit"]: break
    print("Bot:", get_response(user))
 """
# Out:
# ' while True:\n    user = input("You: ")\n    if user.lower() in ["quit","exit"]: break\n    print("Bot:", get_response(user))\n '

# %%
def send_message():
    user_msg = entry.get()
    if not user_msg.strip():
        return
    chat_window.config(state=tk.NORMAL)
    chat_window.insert(tk.END, "You: " + user_msg + "\n")
    chat_window.insert(tk.END, "Bot: " + get_response(user_msg) + "\n\n")
    chat_window.config(state=tk.DISABLED)
    chat_window.see(tk.END)
    entry.delete(0, tk.END)

# Create window
root = tk.Tk()
root.title("AI Chatbot")
root.geometry("500x500")

# Chat display area
chat_window = scrolledtext.ScrolledText(root, wrap=tk.WORD)
chat_window.config(state=tk.DISABLED)
chat_window.pack(padx=10, pady=10, fill=tk.BOTH, expand=True)

# User entry
entry_frame = tk.Frame(root)
entry_frame.pack(fill=tk.X, padx=10, pady=5)

entry = tk.Entry(entry_frame, font=("Arial", 12))
entry.pack(side=tk.LEFT, fill=tk.X, expand=True, padx=(0,5))
entry.bind("<Return>", lambda event: send_message())  # send on Enter key

send_button = tk.Button(entry_frame, text="Send", command=send_message)
send_button.pack(side=tk.RIGHT)

root.mainloop()
